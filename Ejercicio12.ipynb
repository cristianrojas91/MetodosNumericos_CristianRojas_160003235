# %% [markdown]
# # Ejercicios 9.1 al 9.8  Metodos Numericos
#
# Estudiante: Cristian Alexander Rojas Aza
#
# Codigo: 160003235

# %% [markdown]
# # Ejercicio 9.1
#
# a) Forma Matricial:
#
# $\begin{pmatrix}
# 0 & 2 & 5 \\
# 1 & 0 & 1 \\
# 8 & 3 & 0
# \end{pmatrix}$
# $\begin{pmatrix}
# x_1 \\
# x_2\\
# x_3
# \end{pmatrix}$
# =
# $\begin{pmatrix}
# 50 \\
# 10 \\
# 20
# \end{pmatrix}$

# %% [markdown]
# b) Matrix Transpuesta de coeficientes:
#
# $\begin{pmatrix}
# 0 & 1 & 8 \\
# 2 & 0 & 3 \\
# 5 & 1 & 0
# \end{pmatrix}$

# %% [markdown]
# # Ejercicio 9.2
#
# #### a) Dimensiones de las Matrices:
#
# [A]= 3x2
#
# [B]= 3x3
#
# [C]= 3x1
#
# [D]= 2x4
#
# [E]= 3x3
#
# [F]= 2x3
#
# [G]= 1x3

# %% [markdown]
# #### b) Matrices:
#
# Cuadradas: [B] y [E]
#
# Columna: [C]
#
# Renglon: [G]

# %% [markdown]
# #### c) Valores de los Elementos:
#
# a12 = 7
#
# b23 = 7
#
# d32 = N/A
#
# e22 = 2
#
# f12 = 0
#
# g12 = 6

# %% [markdown]
# #### d) Operaciones:
#
# 1) [E] + [B] =
# $\begin{pmatrix}
# 5 & 8 & 15 \\
# 8 & 4 & 10 \\
# 5 & 0 & 10
# \end{pmatrix}$
#
# 2) [A] + [F] = N/A
#
# 3) [B] - [E] =
# $\begin{pmatrix}
# 3 & -2 & 1 \\
# -6 & 0 & 4 \\
# -3 & 0 & -2
# \end{pmatrix}$
#
# 4) 7 x [B] =
# $\begin{pmatrix}
# 28 & 21 & 49 \\
# 7 & 14 & 49 \\
# 7 & 0 & 28
# \end{pmatrix}$
#
# 5) [E] x [B] =
# $\begin{pmatrix}
# 17 & 13 & 74 \\
# 33 & 25 & 75 \\
# 22 & 12 & 52
# \end{pmatrix}$
#
# 6) {B}^T =
#
#
# 7) [B] x [A] =
# $\begin{pmatrix}
# 54 & 76 \\
# 41 & 53 \\
# 24 & 31
# \end{pmatrix}$
#
# 8) [D]^T =
# $\begin{pmatrix}
# 9 & 2 \\
# 4 & -1 \\
# 3 & 7 \\
# -6 & 5
# \end{pmatrix}$
#
# 9) [A] x {C} =
#
#
# 10) [I] x [B] =
# $\begin{pmatrix}
# 4 & 3 & 7 \\
# 1 & 2 & 7 \\
# 1 & 0 & 4
# \end{pmatrix}$
#
# 11) [E]^T [E] =
# $\begin{pmatrix}
# 66 & 19 & 53 \\
# 19 & 29 & 46 \\
# 53 & 46 & 109
# \end{pmatrix}$
#
# 12) {C}^T {C} =

# %% [markdown]
# # Ejercicio 9.3
#
# #### a) Multiplicaciones posiibles:
#
# 1) [A] x [B] =
# $\begin{pmatrix}
# 4 & 15 \\
# 8 & 29 \\
# 9 & 29
# \end{pmatrix}$
#
# 2) [A] x [C] =
# $\begin{pmatrix}
# -16 & 4 \\
# -24 & 4 \\
# 2 & -10
# \end{pmatrix}$
#
# 3) [B] x [C] =
# $\begin{pmatrix}
# -7 & 1 \\
# -5 & 1
# \end{pmatrix}$
#
# 4) [C] X [B] =
# $\begin{pmatrix}
# 1 & 2 \\
# -2.5 & -7
# \end{pmatrix}$
#
# #### b) Explicacion:
#
# No se puede multiplicar a las demas parejas porque el numero de Columnas
# de B no coinciden con el numero de filas de A y lo mismo sucede con C y A
# respectivamente. Es decir, las dimensiones interiores no son iguales y asi
# es imposible la multiplicacion.
#
# #### c) Explicacion:
#
# Los resultados del inciso "a" nos muestran claramente que cuando dos matrices
# son cuadradas no hay ningun problema al ejecutar la maultiplicacion, pero si ambas
# matrices tienen diferentes dimensiones, se tuvo en cuenta, que el numero de columnas
# de la primera matriz debe ser igual en dimension al numero de filas de la segunda matriz
# y de esta forma si se puso ejecutar la multiplicacion. Ademas las dimesiones externas nos
# definio las dimensiones del resultado de la multiplicacion.

# %% [markdown]
# # Ejercicio 9.4
#
# Metodo grafico:

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import math
import sys
import matplotlib.pyplot as pl

x1=[]
y1=[]
x2=[]
y2=[]

def funcion():
    
    global x1,y1,x2,y2
    x=3.0
    while(x<=5.0):
        
        total1 = ((1.0/2.0)*x) + 3.0
        total2 = ((-1.0/6.0)*x) + (34.0/6.0)
        x1.append(x)
        y1.append(total1)
        x2.append(x)
        y2.append(total2)
        x=x+0.5
        
def graficar():
    
    global x1,y1,x2,y2
    pl.plot(x1,y1,"r", label="funcion1")
    pl.plot(x2,y2,"b", label="funcion2")
    pl.title("Solucion Grafica")
    pl.legend(loc="upper center")
    pl.grid()
    pl.show()
            
def main():
    funcion()
    graficar()
    
if __name__ == "__main__":
    main()

# %% [markdown]
# Solucion:
#
# x1 = 4
#
# x2 = 5
#
# Comprobamos:
#
# 4(4) - 8(5) = -24
#
# (4) + 6(5) = 34

# %% [markdown]
# # Ejercicio 9.5
#
# #### a) Solucion por el Metodo Grafico:

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import math
import sys
import matplotlib.pyplot as pl

x1=[]
y1=[]
x2=[]
y2=[]

def funcion():
    
    global x1,y1,x2,y2
    x=200.0
    while(x<=800.0):
        
        total1 = ((11.0/100.0)*x) + 12.0
        total2 = ((2.0/17.4)*x) + 10.0
        x1.append(x)
        y1.append(total1)
        x2.append(x)
        y2.append(total2)
        x=x+0.5
        
def graficar():
    
    global x1,y1,x2,y2
    pl.plot(x1,y1,"r", label="funcion1")
    pl.plot(x2,y2,"b", label="funcion2")
    pl.title("Solucion Grafica")
    pl.legend(loc="upper center")
    pl.grid()
    pl.show()
            
def main():
    funcion()
    graficar()
    
if __name__ == "__main__":
    main()

# %% [markdown]
# RTA: Por el metodo grafico podemos ver que el sistema esta mal condicionado pues
# las pendientes son tan cercanas que es difícil detectar visualmente el punto de interseccion.

# %% [markdown]
# #### b) Que se espera con respecto de la condicion del sistema?
#
# Sobre la base de la solucion grafica, se espera que encontremos un sistema mal
# condicionado ya que claramente se ve que las pendientes estan tan cercanas que es
# dificil detectar visualmente el punto de interseccion y este tipo de sistemas son
# extremadamente sensibles a los errores de redondeo.

# %% [markdown]
# #### c) Determinante:
#
# det[A] =
# $\begin{pmatrix}
# -1.1 & 10 \\
# -2 & 17.4
# \end{pmatrix}$
# = (-1.1) * (17.4) - (-2) * (10) = 0.86

# %% [markdown]
# #### d) Eliminacion de incognitas:
#
# x2 =
# $\begin{equation}
# \frac{(-1.1)*(174.0)-(-2.0)*(120.0)}{(-1.1)*(17.4)-(10.0)*(-2.0)}
# \end{equation}$
# = 56.511627907
#
# x1 =
# $\begin{equation}
# \frac{(174)*(120)-(10)*(174)}{(-1.1)*(17.4)-(10.0)*(-2.0)}
# \end{equation}$
# = 404.65

# %% [markdown]
# # Ejercicio 9.6
#
# #### a) Determinante:
#
# det[A] =
# $\begin{pmatrix}
# 0 & 2 & 5 \\
# 2 & 1 & 1 \\
# 3 & 1 & 0
# \end{pmatrix}$
# = 1

# %% [markdown]
# #### b) Regla de Cramer:
#
# det[A] =
# $\begin{pmatrix}
# 0 & 2 & 5 \\
# 2 & 1 & 1 \\
# 3 & 1 & 0
# \end{pmatrix}$
# = 1
#
# A1 =
# $\begin{pmatrix}
# 9 & 2 & 5 \\
# 9 & 1 & 1 \\
# 10 & 1 & 0
# \end{pmatrix}$
# = 6
#
# A2 =
# $\begin{pmatrix}
# 0 & 9 & 5 \\
# 2 & 9 & 1 \\
# 3 & 10 & 0
# \end{pmatrix}$
# = -8
#
# A3 =
# $\begin{pmatrix}
# 0 & 2 & 9 \\
# 2 & 1 & 9 \\
# 3 & 1 & 10
# \end{pmatrix}$
# = 5
#
# x1 =
# $\begin{equation}
# \frac{A1}{det[A]}
# \end{equation}$
# = 6
#
# x2 =
# $\begin{equation}
# \frac{A2}{det[A]}
# \end{equation}$
# = -8
#
# x3 =
# $\begin{equation}
# \frac{A3}{det[A]}
# \end{equation}$
# = 5

# %% [markdown]
# #### c) Comprobamos:
#
# 2(-8) + 5(5) = 9
#
# 2(6) + (-8) + (5) = 9
#
# 3(6) + (-8) = 10

# %% [markdown]
# #Ejercicio 9.7
#
# #### a) Forma Grafica:

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import math
import sys
import matplotlib.pyplot as pl

x1=[]
y1=[]
x2=[]
y2=[]

def funcion():
    
    global x1,y1,x2,y2
    x=-100.0
    while(x<=100.0):
        
        total1 = ((0.5)*x) + 9.5
        total2 = ((1.02/2.0)*x) + (18.8/2.0)
        x1.append(x)
        y1.append(total1)
        x2.append(x)
        y2.append(total2)
        x=x+0.5
        
def graficar():
    
    global x1,y1,x2,y2
    pl.plot(x1,y1,"r", label="funcion1")
    pl.plot(x2,y2,"b", label="funcion2")
    pl.title("Solucion Grafica")
    pl.legend(loc="upper center")
    pl.grid()
    pl.show()
            
def main():
    funcion()
    graficar()
    
if __name__ == "__main__":
    main()

# %% [markdown]
# #### b) Determinante:
#
# det[A] =
# $\begin{pmatrix}
# 0.5 & -1 \\
# 1.02 & -2
# \end{pmatrix}$
# = (0.5) * (-2) - (1.02) * (-1) = 0.02

# %% [markdown]
# #### c) Respecto de la condicion del Sistema:
#
# Es de esperarse que encontremos un sistema mal condicionado ya que claramente
# se ve que las pendientes estan tan cercanas que es dificil detectar visualmente
# el punto de interseccion.

# %% [markdown]
# #### d) Eliminacion de incognitas:
#
# x2 =
# $\begin{equation}
# \frac{(0.5)*(-18.8)-(1.02)*(-9.5)}{(0.5)*(-2)-(-1)*(1.02)}
# \end{equation}$
# = 14.5
#
# x1 =
# $\begin{equation}
# \frac{(-2)*(-9.5)-(-1)*(-18.8)}{(0.5)*(-2)-(-1)*(1.02)}
# \end{equation}$
# = 10

# %% [markdown]
# #### e) Eliminacion de incognitas usando (a11 = 0.52):
#
# x2 =
# $\begin{equation}
# \frac{(0.52)*(-18.8)-(1.02)*(-9.5)}{(0.52)*(-2)-(-1)*(1.02)}
# \end{equation}$
# = 4.3
#
# x1 =
# $\begin{equation}
# \frac{(-2)*(-9.5)-(-1)*(-18.8)}{(0.52)*(-2)-(-1)*(1.02)}
# \end{equation}$
# = -10
#
# Al modificar a11=0.52 nos dan nuevos resultados en x1 y x2, pero
# igualmente satisfacen la ecuacion.

# %% [markdown]
# # Ejercicio 9.8
#
# ### a) Por eliminacion de Gauss Simple:
#
# #####Matriz Original
# $\begin{pmatrix}
# 10 & 2 & -3 & 27\\
# -3 & -6 & 2 & -61.5\\
# 1  & 1  & 5 & -21.5
# \end{pmatrix}
# $
#
# #####R1-> (1/10)*R1
# $\begin{pmatrix}
# 1 & 0.2 & -0.3 & 2.7\\
# -3 & -6 & 2 & -61.5\\
# 1  & 1  & 5 & -21.5
# \end{pmatrix}
# $
#
# #####R2->3*R1+R2
# #####R3->(-R1)+R3
# $\begin{pmatrix}
# 1 & 1/5 & -1/10 & 27/10\\
# 0 & -27/5 & 17/10 & -267/6\\
# 0 & 4/5  & 51/10 & -121/5
# \end{pmatrix}
# $
#
# #####R2->(-5/27)R2
# $\begin{pmatrix}
# 1 & 1/5 & -1/10 & 27/10\\
# 0 & 1 & -17/54 & 89/9\\
# 0 & 4/5  & 51/10 & -121/5
# \end{pmatrix}
# $
#
# #####R3->(-4/5)R2+R3
# $\begin{pmatrix}
# 1 & 1/5 & -1/10 & 27/10\\
# 0 & 1 & -17/54 & 89/9\\
# 0 & 0 & 289/54 & -289/9
# \end{pmatrix}
# $
#
# #####R3->(54/289)R3
# $\begin{pmatrix}
# 1 & 1/5 & -1/10 & 27/10\\
# 0 & 1 & -17/54 & 89/9\\
# 0 & 0 & 1 & -6
# \end{pmatrix}
# $
#
# #####Terminado la eliminacion hacia adelante comenzamos con la eliminacion hacia atras
#
# x3=-6
#
# 0 + x2 - 17/54 x3 = 89/9 ----> x2 = 89/9 + (17/54)(-6) = 8
#
# x1 + 1/5 x2 -1/10 x3 = 27/10 ----> x1 = 27/10 - (1/5)(8) + (1/10)(-6) = 1/2
#
#
# #####Valores de las incognitas
#
# X1= 1/2
#
# X2= 8
#
# X3= -6
#
#
# ### b) Comprobamos:
#
# 10(1/2) + 2(8) – (-6) = 27
#
# –3(1/2) – 6(8) + 2(-6) = –61.5
#
# (1/2) + (8) + 5(-6) = –21.5
